# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bac=pd.read_csv('BAC.csv')
bac.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2006-01-03  46.919998  47.180000  46.150002  47.080002  34.811729  16296700
# 1  2006-01-04  47.000000  47.240002  46.450001  46.580002  34.442013  17757900
# 2  2006-01-05  46.580002  46.830002  46.320000  46.639999  34.486385  14970700
# 3  2006-01-06  46.799999  46.910000  46.349998  46.570000  34.434616  12599800
# 4  2006-01-09  46.720001  46.970001  46.360001  46.599998  34.456806  15619400
# 5  2006-01-10  46.400002  46.509998  45.880001  46.209999  34.168419  15634600
# 6  2006-01-11  46.060001  46.250000  45.750000  46.099998  34.087093  14742100
# 7  2006-01-12  46.220001  46.230000  45.709999  45.799999  33.865276  10546600
# 8  2006-01-13  45.830002  46.000000  45.680000  45.799999  33.865276  10791000
# 9  2006-01-17  45.400002  45.580002  45.000000  45.310001  33.502972  14605900

# %%
bac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   object
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.8+ KB

# %%
bac['Date']=bac['Date'].astype('datetime64[ns]')
bac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   datetime64[ns]
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.8 KB

# %%
bac['Year']=bac['Date'].dt.year

yearly_data=bac.groupby('Year')['Close'].mean().reset_index()

sns.lineplot(yearly_data,x='Year',y='Close',marker='o',color='red')
plt.title("BAC-Stock close avg price over years")
plt.grid(True)
plt.show()

# %%
sns.scatterplot(bac,x='Open',y='Close')
plt.title('Open price VS Close price')
plt.grid(True)
plt.show()

# %%
citi=pd.read_csv('C.csv')
citi['Date']=citi['Date'].astype('datetime64[ns]')
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   datetime64[ns]
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.8 KB

# %%
citi["Year_c"]=citi['Date'].dt.year
yearly_volume=citi.groupby("Year_c")['Volume'].sum().reset_index()

sns.barplot(data=yearly_volume,x="Year_c",y="Volume")
plt.title('Total Trading Volumne by Year')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(data=citi[['Open','Close','Low','High','Volume']].corr(),annot=True,cmap='coolwarm',center=0,linewidth=.5)
plt.title("Correlation Matrix of Stock Prices and Volume")
plt.show()

# %%
gold=pd.read_csv('GS.csv')
gold['Date']=gold['Date'].astype('datetime64[ns]')
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   datetime64[ns]
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.8 KB

# %%
gold['Year_g']=gold['Date'].dt.year
filtered_gold=gold[(gold['Year_g']>=2010) & (gold['Year_g']<=2020)]


plt.figure(figsize=(14,7))
sns.boxplot(data=filtered_gold,x='Year_g',y='Close',palette='deep',hue='Year_g',dodge=False)
plt.title('Daily Closing Prices By Year (2010-2020)')
plt.xlabel("Year")
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the pair plot
pair_plot = sns.pairplot(data=gold)
pair_plot.fig.suptitle("Pair-Plot", y=1.02)  # Adjust title position

# Display the plot
plt.show()

# %%
jpm=pd.read_csv('JPM.csv')
jpm['Date']=jpm['Date'].astype('datetime64[ns]')
jpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   datetime64[ns]
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.8 KB

# %%
from matplotlib.ticker import FuncFormatter
plt.figure(figsize=(14,7))
sns.histplot(jpm['Volume'],bins=20,kde=True,color='green')

def millions(x,pos):
    return '%1.1fM' % (x * 1e-6)
plt.gca().xaxis.set_major_formatter(FuncFormatter(millions))
plt.title('Distribution of Trading Volume')
plt.show()

# %%
morgan=pd.read_csv('MS.csv')
morgan['Date']=morgan['Date'].astype('datetime64[ns]')
morgan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   datetime64[ns]
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 192.8 KB

# %%
morgan['Price_Category'] = ['High' if x > morgan['Close'].mean() else 'Low' for x in morgan['Close']]

# Create the count plot
plt.figure(figsize=(14, 7))
sns.countplot(data=morgan, x='Price_Category', palette='coolwarm')
plt.title('Count of High and Low Prices')
plt.xlabel('Price Category')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-20-6f74cf2ca960>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=morgan, x='Price_Category', palette='coolwarm')
